# %% [markdown]
# <a href="https://colab.research.google.com/github/HARI03SH/MY-FIRST-REPOSITORY/blob/main/MY_FIRST_REPOSITORY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input())
b=int(input())
print(a+b)
# Out:
# 10
# 20
# 30
